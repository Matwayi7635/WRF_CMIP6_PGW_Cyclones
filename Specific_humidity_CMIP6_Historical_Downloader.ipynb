# %%
#https://stackoverflow.com/questions/75143586/issue-to-automize-download-of-data-with-cds-api
import cdsapi
import urllib3

urllib3.disable_warnings()
c = cdsapi.Client()

models = ['access_cm2', 'ciesm','cmcc_esm2','inm_cm5_0', 'mpi_esm1_2_lr']#,#'FGOALS-f3-L','FIO-ESM-2-0','CNRM-CM6-1','INM-CM4-8','IPSL-CM6A-LR',
#'MIROC6','HadGEM3-GC31-MM','MPI-ESM1-2-LR','MRI-ESM2-0','NorESM2-MM','ACCESS-ESM1-5','CESM2']


params = {
'format': 'zip',
'temporal_resolution': 'monthly',
'experiment': 'historical',
'variable': 'specific_humidity',
#'model': 'access_cm2',
'month': [
    '01', '02', '03',
    '04', '05',
],
'year': [
    #'1950', #'1951', '1952',
    #'1953', '1954', '1955',
    #'1956', '1957', '1958',
    '1959', '1960', '1961',
    '1962', '1963', '1964',
    '1965', '1966', '1967',
    '1968', '1969', '1970',
    '1971', '1972', '1973',
    '1974', '1975', '1976',
    '1977', '1978', '1979',
    '1980', '1981', '1982',
    '1983', '1984', '1985',
    '1986', '1987', '1988',
    '1989', '1990', '1991',
    '1992', '1993', '1994',
    '1995', '1996', '1997',
    '1998', '1999', '2000',
],
'area': [
    90, -180, -90,
    180,
],
'level': [
    '1', '5', '10',
    '20', '30', '50',
    '70', '100', '150',
    '200', '250', '300',
    '400', '500', '600',
    '700', '850', '925',
    '1000',
],
}
for model in models:
    params['model'] = model
    c.retrieve('projections-cmip6', params, f'Specific_humidity_{model}_Hist_Pressure_level_1960_2000.zip')
# Out:
# 2023-10-18 13:22:34,366 INFO Welcome to the CDS
# 2023-10-18 13:22:34,368 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 13:22:34,607 INFO Request is queued
# 2023-10-18 13:22:35,839 INFO Request is running
# 2023-10-18 13:24:30,248 INFO Request is completed
# 2023-10-18 13:24:30,253 INFO Downloading https://download-0018.copernicus-climate.eu/cache-compute-0018/cache/data6/adaptor.esgf_wps.retrieve-1697606591.013496-5388-16-077316f5-bca8-4e41-a2d0-3265117ec3dc.zip to Specific_humidity_access_cm2_Hist_Pressure_level_1960_2000.zip (334.9M)
# 2023-10-18 13:28:13,160 ERROR Download interupted: HTTPSConnectionPool(host='download-0018.copernicus-climate.eu', port=443): Read timed out.
# 2023-10-18 13:28:13,160 ERROR Download incomplete, downloaded 139920384 byte(s) out of 351126779
# 2023-10-18 13:28:13,161 WARNING Sleeping 10 seconds
# 2023-10-18 13:28:23,170 WARNING Resuming download at byte 139920384
# 2023-10-18 13:30:36,804 INFO Download rate 935.5K/s
# 2023-10-18 13:30:37,995 INFO Welcome to the CDS
# 2023-10-18 13:30:37,995 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 13:30:38,283 INFO Request is queued
# 2023-10-18 13:30:39,518 INFO Request is running
# 2023-10-18 13:33:31,860 INFO Request is completed
# 2023-10-18 13:33:31,863 INFO Downloading https://download-0009-clone.copernicus-climate.eu/cache-compute-0009/cache/data9/adaptor.esgf_wps.retrieve-1697607098.2804902-11346-15-c7808f7f-e118-438e-96a5-2d13db499304.zip to Specific_humidity_ciesm_Hist_Pressure_level_1960_2000.zip (638.4M)
# 2023-10-18 13:41:35,144 INFO Download rate 1.3M/s
# 2023-10-18 13:41:36,319 INFO Welcome to the CDS
# 2023-10-18 13:41:36,321 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 13:41:36,587 INFO Request is queued
# 2023-10-18 13:41:37,815 INFO Request is running
# 2023-10-18 13:43:32,211 INFO Request is completed
# 2023-10-18 13:43:32,212 INFO Downloading https://download-0020.copernicus-climate.eu/cache-compute-0020/cache/data0/adaptor.esgf_wps.retrieve-1697607782.4446821-29767-14-68dcf422-86b8-4db8-89bd-338805be3e96.zip to Specific_humidity_cmcc_esm2_Hist_Pressure_level_1960_2000.zip (508.8M)
# 2023-10-18 13:49:56,973 INFO Download rate 1.3M/s
# 2023-10-18 13:49:58,121 INFO Welcome to the CDS
# 2023-10-18 13:49:58,122 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 13:49:58,432 INFO Request is queued
# 2023-10-18 13:49:59,660 INFO Request is running
# 2023-10-18 13:50:49,515 INFO Request is completed
# 2023-10-18 13:50:49,517 INFO Downloading https://download-0007-clone.copernicus-climate.eu/cache-compute-0007/cache/data7/adaptor.esgf_wps.retrieve-1697608227.8157194-20229-13-c32e3bc5-0c4a-4e37-a979-7ca572f76890.zip to Specific_humidity_inm_cm5_0_Hist_Pressure_level_1960_2000.zip (215.9M)
# 2023-10-18 13:56:09,158 INFO Download rate 691.7K/s
# 2023-10-18 13:56:10,343 INFO Welcome to the CDS
# 2023-10-18 13:56:10,344 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 13:56:10,654 INFO Request is queued
# 2023-10-18 13:56:11,900 INFO Request is running
# 2023-10-18 13:57:27,671 INFO Request is completed
# 2023-10-18 13:57:27,672 INFO Downloading https://download-0002-clone.copernicus-climate.eu/cache-compute-0002/cache/data7/adaptor.esgf_wps.retrieve-1697608600.3578906-31846-14-bf372830-58e2-4a36-a00e-efac2d808e6b.zip to Specific_humidity_mpi_esm1_2_lr_Hist_Pressure_level_1960_2000.zip (122.9M)
# 2023-10-18 13:59:27,859 INFO Download rate 1M/s

# %%
#https://stackoverflow.com/questions/75143586/issue-to-automize-download-of-data-with-cds-api
import cdsapi
import urllib3

urllib3.disable_warnings()
c = cdsapi.Client()

models = ['access_cm2', 'ciesm','cmcc_esm2','inm_cm5_0', 'mpi_esm1_2_lr']#,#'FGOALS-f3-L','FIO-ESM-2-0','CNRM-CM6-1','INM-CM4-8','IPSL-CM6A-LR',
#'MIROC6','HadGEM3-GC31-MM','MPI-ESM1-2-LR','MRI-ESM2-0','NorESM2-MM','ACCESS-ESM1-5','CESM2']


params = {
'format': 'zip',
'temporal_resolution': 'monthly',
        'experiment': 'ssp2_4_5',
        'variable': 'specific_humidity',
        'level': [
            '1', '5', '10',
            '20', '30', '50',
            '70', '100', '150',
            '200', '250', '300',
            '400', '500', '600',
            '700', '850', '925',
            '1000',
        ],
        'model': 'access_cm2',
        'year': [
            '2060', '2061', '2062',
            '2063', '2064', '2065',
            '2066', '2067', '2068',
            '2069', '2070', '2071',
            '2072', '2073', '2074',
            '2075', '2076', '2077',
            '2078', '2079', '2080',
            '2081', '2082', '2083',
            '2084', '2085', '2086',
            '2087', '2088', '2089',
            '2090', '2091', '2092',
            '2093', '2094', '2095',
            '2096', '2097', '2098',
            '2099', '2100',
        ],
        'month': [
            '01', '02', '03',
            '04', '05',
        ],
        'area': [
            90, -180, -90,
            180,
],
}
for model in models:
    params['model'] = model
    c.retrieve('projections-cmip6', params, f'Specific_humidity_{model}_SSP245_Pressure_level_2060_2100.zip')
# Out:
# 2023-10-18 14:10:33,296 INFO Welcome to the CDS
# 2023-10-18 14:10:33,297 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 14:10:33,559 INFO Request is queued
# 2023-10-18 14:10:34,788 INFO Request is running
# 2023-10-18 14:12:29,708 INFO Request is completed
# 2023-10-18 14:12:29,708 INFO Downloading https://download-0002-clone.copernicus-climate.eu/cache-compute-0002/cache/data7/adaptor.esgf_wps.retrieve-1697609469.6040955-10127-15-742e8e62-b53c-4e9b-899b-636ccf161f6e.zip to Specific_humidity_access_cm2_SSP245_Pressure_level_2060_2100.zip (327.9M)
# 2023-10-18 14:20:17,065 INFO Download rate 718.4K/s
# 2023-10-18 14:20:18,256 INFO Welcome to the CDS
# 2023-10-18 14:20:18,257 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 14:20:18,549 INFO Request is queued
# 2023-10-18 14:20:19,784 INFO Request is running
# 2023-10-18 14:23:12,136 INFO Request is completed
# 2023-10-18 14:23:12,139 INFO Downloading https://download-0010-clone.copernicus-climate.eu/cache-compute-0010/cache/data0/adaptor.esgf_wps.retrieve-1697610087.5587518-12562-13-22f4f16b-697a-483b-ba9d-58a77a6549e8.zip to Specific_humidity_ciesm_SSP245_Pressure_level_2060_2100.zip (634.9M)
# 2023-10-18 14:32:26,123 INFO Download rate 1.1M/s
# 2023-10-18 14:32:27,289 INFO Welcome to the CDS
# 2023-10-18 14:32:27,290 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 14:32:27,564 INFO Request is queued
# 2023-10-18 14:32:28,815 INFO Request is running
# 2023-10-18 14:34:23,239 INFO Request is completed
# 2023-10-18 14:34:23,240 INFO Downloading https://download-0003-clone.copernicus-climate.eu/cache-compute-0003/cache/data9/adaptor.esgf_wps.retrieve-1697610821.0465448-22193-15-f5477979-da6a-4c19-a682-df8ff5e5d765.zip to Specific_humidity_cmcc_esm2_SSP245_Pressure_level_2060_2100.zip (507.7M)
# 2023-10-18 14:43:16,769 INFO Download rate 974.5K/s
# 2023-10-18 14:43:17,937 INFO Welcome to the CDS
# 2023-10-18 14:43:17,938 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 14:43:18,261 INFO Request is queued
# 2023-10-18 14:43:19,495 INFO Request is running
# 2023-10-18 14:44:09,379 INFO Request is completed
# 2023-10-18 14:44:09,380 INFO Downloading https://download-0020.copernicus-climate.eu/cache-compute-0020/cache/data0/adaptor.esgf_wps.retrieve-1697611425.1925085-2125-17-3d5e6c3b-6685-4fb1-972a-2be52f1eaeb2.zip to Specific_humidity_inm_cm5_0_SSP245_Pressure_level_2060_2100.zip (212.1M)
# 2023-10-18 14:46:05,793 INFO Download rate 1.8M/s
# 2023-10-18 14:46:06,997 INFO Welcome to the CDS
# 2023-10-18 14:46:07,001 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 14:46:07,307 INFO Request is queued
# 2023-10-18 14:46:08,543 INFO Request is running
# 2023-10-18 14:46:58,456 INFO Request is completed
# 2023-10-18 14:46:58,458 INFO Downloading https://download-0007-clone.copernicus-climate.eu/cache-compute-0007/cache/data4/adaptor.esgf_wps.retrieve-1697611594.3863623-15920-18-370103b5-d92e-4c68-bdc4-26b873a5b74c.zip to Specific_humidity_mpi_esm1_2_lr_SSP245_Pressure_level_2060_2100.zip (120.7M)
# 2023-10-18 14:47:30,259 INFO Download rate 3.8M/s

# %%
#https://stackoverflow.com/questions/75143586/issue-to-automize-download-of-data-with-cds-api
import cdsapi
import urllib3

urllib3.disable_warnings()
c = cdsapi.Client()

models = ['access_cm2', 'ciesm','cmcc_esm2','inm_cm5_0', 'mpi_esm1_2_lr']#,#'FGOALS-f3-L','FIO-ESM-2-0','CNRM-CM6-1','INM-CM4-8','IPSL-CM6A-LR',
#'MIROC6','HadGEM3-GC31-MM','MPI-ESM1-2-LR','MRI-ESM2-0','NorESM2-MM','ACCESS-ESM1-5','CESM2']


params = {
'format': 'zip',
'temporal_resolution': 'monthly',
        'experiment': 'ssp5_8_5',
        'variable': 'specific_humidity',
        'level': [
            '1', '5', '10',
            '20', '30', '50',
            '70', '100', '150',
            '200', '250', '300',
            '400', '500', '600',
            '700', '850', '925',
            '1000',
        ],
        #'model': 'access_cm2',
        'year': [
            '2060', '2061', '2062',
            '2063', '2064', '2065',
            '2066', '2067', '2068',
            '2069', '2070', '2071',
            '2072', '2073', '2074',
            '2075', '2076', '2077',
            '2078', '2079', '2080',
            '2081', '2082', '2083',
            '2084', '2085', '2086',
            '2087', '2088', '2089',
            '2090', '2091', '2092',
            '2093', '2094', '2095',
            '2096', '2097', '2098',
            '2099', '2100',
        ],
        'month': [
            '01', '02', '03',
            '04', '05',
        ],
        'area': [
            90, -180, -90,
            180,
],
}
for model in models:
    params['model'] = model
    c.retrieve('projections-cmip6', params, f'Specific_humidity_{model}_SSP585_Pressure_level_2060_2100.zip')
# Out:
# 2023-10-18 14:55:16,771 INFO Welcome to the CDS
# 2023-10-18 14:55:16,771 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 14:55:17,049 INFO Request is queued
# 2023-10-18 14:55:18,283 INFO Request is running
# 2023-10-18 14:58:10,609 INFO Request is completed
# 2023-10-18 14:58:10,611 INFO Downloading https://download-0015-clone.copernicus-climate.eu/cache-compute-0015/cache/data7/adaptor.esgf_wps.retrieve-1697612150.0065439-29454-18-0bbe7a0a-a23c-4f35-b3ff-d680f7f29475.zip to Specific_humidity_access_cm2_SSP585_Pressure_level_2060_2100.zip (329.8M)
# 2023-10-18 15:06:41,014 INFO Download rate 661.7K/s
# 2023-10-18 15:06:42,184 INFO Welcome to the CDS
# 2023-10-18 15:06:42,186 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 15:06:42,476 INFO Request is queued
# 2023-10-18 15:06:43,708 INFO Request is running
# 2023-10-18 15:09:36,029 INFO Request is completed
# 2023-10-18 15:09:36,031 INFO Downloading https://download-0000-clone.copernicus-climate.eu/cache-compute-0000/cache/data4/adaptor.esgf_wps.retrieve-1697612869.9728708-15750-13-6cb19600-8266-4422-935a-a645c6558512.zip to Specific_humidity_ciesm_SSP585_Pressure_level_2060_2100.zip (637.3M)
# 2023-10-18 15:26:23,325 INFO Download rate 647.9K/s
# 2023-10-18 15:26:24,501 INFO Welcome to the CDS
# 2023-10-18 15:26:24,503 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 15:26:24,787 INFO Request is queued
# 2023-10-18 15:26:26,024 INFO Request is running
# 2023-10-18 15:29:18,409 INFO Request is completed
# 2023-10-18 15:29:18,409 INFO Downloading https://download-0008-clone.copernicus-climate.eu/cache-compute-0008/cache/data5/adaptor.esgf_wps.retrieve-1697614128.880843-24699-18-c3ec24a9-8740-4bcd-afd0-5d6b9d6b615a.zip to Specific_humidity_cmcc_esm2_SSP585_Pressure_level_2060_2100.zip (511.6M)
# 2023-10-18 15:36:25,222 INFO Download rate 1.2M/s
# 2023-10-18 15:36:26,399 INFO Welcome to the CDS
# 2023-10-18 15:36:26,400 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 15:36:26,690 INFO Request is queued
# 2023-10-18 15:36:27,931 INFO Request is running
# 2023-10-18 15:37:43,724 INFO Request is completed
# 2023-10-18 15:37:43,725 INFO Downloading https://download-0001-clone.copernicus-climate.eu/cache-compute-0001/cache/data6/adaptor.esgf_wps.retrieve-1697614637.7242553-24265-12-b4573b8a-fc76-44f4-9e74-a29143f0e7f0.zip to Specific_humidity_inm_cm5_0_SSP585_Pressure_level_2060_2100.zip (270.5M)
# 2023-10-18 15:42:08,211 INFO Download rate 1M/s
# 2023-10-18 15:42:09,381 INFO Welcome to the CDS
# 2023-10-18 15:42:09,381 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/projections-cmip6
# 2023-10-18 15:42:09,660 INFO Request is queued
# 2023-10-18 15:42:10,895 INFO Request is running
# 2023-10-18 15:43:00,781 INFO Request is completed
# 2023-10-18 15:43:00,782 INFO Downloading https://download-0011-clone.copernicus-climate.eu/cache-compute-0011/cache/data0/adaptor.esgf_wps.retrieve-1697614953.7486384-24063-8-acc48f0b-a614-4544-b647-cd3ec1b1fba1.zip to Specific_humidity_mpi_esm1_2_lr_SSP585_Pressure_level_2060_2100.zip (120.5M)
# 2023-10-18 15:45:57,503 INFO Download rate 698.1K/s
