# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-


from scipy.io.netcdf import netcdf_file as Dataset
import numpy as np
from scipy.ndimage.filters import gaussian_filter

import matplotlib as mpl
mpl.use('agg')
from mpl_toolkits.basemap import Basemap
from scipy.io import netcdf_file as nc
from pylab import *

from datetime import datetime   ########
from datetime import timedelta  ########
from glob import glob

import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from mpl_toolkits.basemap import Basemap, addcyclic
from scipy.ndimage.filters import minimum_filter, maximum_filter
#from netCDF4 import Dataset

def extrema(mat,mode='wrap',window=10):
    """find the indices of local extrema (min and max)
    in the input array."""
    mn = minimum_filter(mat, size=window, mode=mode)
    mx = maximum_filter(mat, size=window, mode=mode)
    # (mat == mx) true if pixel is equal to the local max
    # (mat == mn) true if pixel is equal to the local in
    # Return the indices of the maxima, minima
    return np.nonzero(mat == mn), np.nonzero(mat == mx)


files1 = glob('gm500*nc')
#files2 = glob('*nc')

#files1 = glob('*nc')
#files1 = glob('*nc')
#files2 = glob('MYD08_*nc')
#files2 = glob('e*nc')

files1.sort()
#files2.sort()

#new
#LONS = -24, 60
#LATS = 0, 60

#old
#LONS = -40, 60
#LATS = -20, 70

LONS = -24, 60
LATS = 10, 65

cmap=cm.RdBu
#cmap=cm.rainbow
#cmap=matplotlib.cm.get_cmap('rainbow_r')

#cmap=cm.bwr
#cmap=cm.spectral
#cmap=cm.jet
#cmap=cm.PRGn
#BOUNDS = np.arange(980, 1028, 2)
#TICKS  = np.arange(980, 1030, 5)

#colors = 'midnightblue','navy','mediumblue','blue','slateblue','mediumslateblue','cadetblue','lightskyblue','lightblue' \
#,'paleturquoise','lightcyan','lavender','white','salmon','lightcoral','tomato','orangered','red'

#colors = 'darkblue','midnightblue','#1e488f','#0165fc', '#247afd'\
#,'#448ee4','#75bbfd','lightskyblue','#a2cffe','lightsteelblue','#c5c9c7','lavender','white','#ffc5cb','lightcoral','tomato','orangered','red'

#over = 'maroon'
#over = '#1d1309' #(darkest)
#under = 'indigo' #(white)

#cmap = mpl.colors.ListedColormap(colors)
#cmap.set_over(over)
#cmap.set_under(under)


BOUNDS = np.arange(5000, 6100, 50)
BOUNDARIES = [5000,6100,50]
LEVS = [BOUNDARIES[0]] + BOUNDS + [BOUNDARIES[1]]


BOUNDS1 = [985,  989,  993,  997, 1001, 1005, 1009, 1013, 1017, 1021,1025, 1029, 1033,1037] 
BOUNDARIES1 = [985, 1037]



LEVS1 = [BOUNDARIES1[0]] + BOUNDS1 + [BOUNDARIES1[1]]


#BOUNDS1 = np.arange(965, 1040,4)
#TICKS1  = np.arange(965,1040,4)
#BOUNDARIES1 = [965,1040,4]
#LEVS1 = [BOUNDARIES1[0]] + BOUNDS1 + [BOUNDARIES1[1]]


#TICKS  = np.arange(1300, 1580, 150)
#MVAL1 = -32767.0
#MVAL1 = -9.96921e+36
FONTSIZE = 8

mpl.rcParams['axes.linewidth'] = 0.5
#print mpl.rcParams

norm1 = mpl.colors.Normalize(vmin=BOUNDS1[0], vmax=BOUNDS1[-1])
#print BOUNDS[0], BOUNDS[-1]



clf()


for item in files1:

    clf()
    #   fig, axes = subplots(nrows=1, ncols=2)
    #f='/home/dream/Downloads/a_final_work/case1_20090701/pressure/n1.nc'

    OUT = item.replace('.nc','').replace('geop_','')
    
    #DREAM
    f1 = nc(item)
    times=f1.variables['time'][72:148] #128 previously sama
    lon = f1.variables['lon'].data
    lat = f1.variables['lat'].data
    lev = f1.variables['lev']
    slp = f1.variables['var151'].data
    var = f1.variables['var129'][:,0,:,:]
    size(var)
    #var = var[:]*var.scale_factor + var.add_offset
    #var = np.ma.masked_equal(var, MVAL1)
    #var1 = np.ma.masked_equal(slp, MVAL1)
    #var1=gaussian_filter(var1, sigma=5)
    var = var/9.8
    var1 = slp/100
    var = gaussian_filter(var, sigma=2) ########################################################
    dims = var.shape
    
    var1 = gaussian_filter(var1, sigma=2) ########################################################
    dims = var1.shape
    print (var.shape, np.max(var), np.min(var))
    print (var1.shape, np.max(var1), np.min(var1))
    #var = var[:]*var.scale_factor + var.add_offset
    
    #var =var / 100.0
    #print var
    #var = np.arange([1,]160, 1, 361, 401)
    #var = numpy.reshape(var,[(160, 361, 401)], order='C')
    #var = np.ma.masked_equal(var, MVAL1)
    #var = var / 9.8
    #var.size
    #print var 
    #var.shape
    #var = np.reshape(var,([:,0,:,:]),'C') #result = x[:, :, 0] print(result.shape)
    #var1 = var[:,0,:,:]
    #size(var1)
    #print(var1.shape)
    #var = f1.variables['msl'].data   
    #
    #var = f(lon,lat)
    
    
    
    ####naba
    #uwnd = f1.variables['u']
    #uwnd = uwnd[:]*uwnd.scale_factor + uwnd.add_offset
    #vwnd = f1.variables['v']
    #vwnd = vwnd[:]*vwnd.scale_factor + vwnd.add_offset
    #uwnd = np.ma.masked_equal(uwnd, MVAL1)
    #vwnd = np.ma.masked_equal(vwnd, MVAL1)
    
    #print size(dims[0]),size(uwnd)
    #var = np.ma.masked_equal(aod, MVAL1).mean(axis=0)
    
    #f1.close()
    #print lon.shape, lat.shape, var.shape, np.min(var), np.max(var)
    #tu = f1.variables['time'].units                      ######
    #tm = tu.replace("hours since","").strip()           ######
    #dt = datetime.strptime(tm, '%Y-%m-%d %H:%M:%S')   ######
    #ts = datetime.strftime(dt, "%d %B %Y %Hh")     

    x, y = meshgrid(lon, lat)
    #var = f(x,y)
    for i in range(dims[0]):
     clf()
        
      #print i
        #print uwnd[i], vwnd[i]
     bmap = Basemap(

        llcrnrlon=LONS[0],
        llcrnrlat=LATS[0],
        urcrnrlon=LONS[1],
        urcrnrlat=LATS[1],
        resolution='l',
     )

        #contourf of pressure
        #co1 = bmap.contour(x, y, var[i], cmap=cmap, levels=BOUNDS)
        #put in evindence contours, I think it's cool but you can comment
     #clevs = np.arange(1,361,401)    
        
     bmap.drawcoastlines(linewidth=.7,color='grey')
     bmap.drawcountries(linewidth=.7,color='grey')
     #bmap.fillcontinents(color='0.8')#,lake_color='aqua',zorder = 0)
        
        
        #bmap.drawmapboundary(fill_color='aqua')
     #bmap.drawmapboundary()
        #m.fillcontinents(color='coral',lake_color='aqua')
        #first timestep no wind
        #if i != 0:
            #draw arrows of wind. Not all, with an interval of three in this case
            #to be more readable, otherwise you'd see a black screen
        
        #barbs = bmap.barbs(x[::5,::5], y[::5,::5], uwnd[i,::5,::5], vwnd[i,::5,::5],length=5,barbcolor='k',flagcolor='r',linewidth=0.5)
        #print var[i]
     bmap.drawparallels(arange(LATS[0]+1,LATS[1],15), labels=[1,0,0,0],fontsize=FONTSIZE)
     bmap.drawmeridians(arange(LONS[0]+1,LONS[1],15), labels=[0,0,0,1],fontsize=FONTSIZE)
     
     
     
     #norm2 = mpl.colors.Normalize(vmin=BOUNDARIES[0], vmax=BOUNDARIES[1])
     
          
     co=bmap.contour(x, y, var[i], colors=('darkgreen'), levels=BOUNDS, linewidths=1.2,fontsize=FONTSIZE-2,extend='both')
     clabel(co,inline=True,fontsize=9,colors='darkgreen',fmt='%g')
     
     #norm1 = mpl.colors.Normalize(vmin=BOUNDARIES1[0], vmax=BOUNDARIES1[1])
     #norm1 = mpl.colors.BoundaryNorm(BOUNDS1, len(BOUNDS1)-1, clip=True)

     #co1=bmap.contour(x, y, var1[i], colors=('dimgrey'), levels=BOUNDS1, linewidths=1.5,fontsize=FONTSIZE-5,extend='both')
     
     #co=bmap.contour(x, y, var1[i], colors=('w'), levels=BOUNDS1, linewidths=1,fontsize=FONTSIZE-5)
     
     co2 = bmap.contourf(x, y, var1[i], levels=BOUNDS1, cmap=cmap, norm=norm1,extend="both")
     #clabel(co2,inline=True,fontsize=13,colors='k',fmt='%g')
     
     #clabel(co1,inline=True,fontsize=13,colors='orangered',fmt='%g')

     
     #co=bmap.contour(x, y, var1[i], colors=('w'), levels=BOUNDS1, linewidths=1.7,fontsize=FONTSIZE-5)
     #clabel(co,inline=True,fontsize=8,colors='w',fmt='%g')
     #co=bmap.contour(x, y, var1[i], colors=('k'), levels=BOUNDS1, linewidths=1.5,fontsize=FONTSIZE-5,extend='both')
        
        #Q = bmap.quiver(x[::5,::5], y[::5,::5], uwnd[i,::5,::5], vwnd[i,::5,::5],scale=150,color='grey',linewidth=.03)  #final
        #Q = m.quiver(x, y, uwnd[i], vwnd[i],scale=150,color='grey',linewidth=.1)
            # the label
        #quiverkey(Q, .95, 1.03, 10, '10 m/s')#,labelpos='W')
        #bmap.drawmapboundary(fill_color='grey')

     TIT1 = item.replace('.nc','').split('_')

     cb = colorbar(co2,
          format='%.0f',
          orientation='vertical',
          ticks=BOUNDS1,
          shrink=0.7,
          pad=.01
          )
     
     tu = f1.variables['time'].units                      ######	  
     tm = tu.replace("hours since","").strip()           ######
     dt = datetime.strptime(tm, '%Y-%m-%d %H:%M:%S')   ######
	  
     dt = dt + timedelta(hours = int(times[i]))
     ts = datetime.strftime(dt, "%d %B %Y %H")          ######
    
     tit = "%02d" % 1
        #forecastTime = int(times[i])
#     title( "%s" "UTC" % (ts),fontsize=7)
     title( 'Geopotential Height(gpm) at 500 hPa & Mean Sea Level Pressure(hPa)',fontsize=7,weight='bold')
     #props = dict(boxstyle='round', facecolor='red', edgecolor='red')
     

     #text(0.5,58, "%s" "UTC" % (ts),color='b', size = 10,bbox=props)#, alpha = -500.0 )#,fancybox= False)
     
     # these are matplotlib.patch.Patch properties
     props = dict(boxstyle='round', facecolor='black', edgecolor='orange',alpha=0.5)

# place a text box in upper left in axes coords
     text(-6, 62, "%s" "UTC" % (ts), color='white',fontsize=9,weight='bold',verticalalignment='baseline', bbox=props,horizontalalignment='center')
     
     #text(0.5, 0.5, 'matplotlib', horizontalalignment='center',
     #verticalalignment='center')#, transform=ax.transAxes)

     #annotate('local max', xy=(3, 1),  xycoords='data',
      #      xytext=(0.8, 0.95), textcoords='axes fraction',
       #     horizontalalignment='right', verticalalignment='top',
        #    )

     
     #suptitle("%s" "UTC" % (ts))
     #fig.suptitle('This is the figure title', fontsize=12)

        #print  OUT, files1.index(item)
     savefig(OUT + "_" + str(i) + ".png", bbox_inches='tight', pad_inches=.3, dpi=150)
