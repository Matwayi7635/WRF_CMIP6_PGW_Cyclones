# %%
import xarray as xr
import os
ds=xr.open_mfdataset('1851228N13313.ibtracs.v03r09.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (center: 3, wmotime: 49, time: 50, speedradius_h: 3, quadrant: 4, speedradius_a: 4)
# Coordinates:
#   * time                   (time) datetime64[ns] 1851-08-16 ... 1851-08-28T06...
# Dimensions without coordinates: center, wmotime, speedradius_h, quadrant, speedradius_a
# Data variables: (12/95)
#     nobs_wmo               int16 ...
#     nobs                   int16 ...
#     genesis_basin          |S2 ...
#     num_basins             int16 ...
#     season                 int16 ...
#     source                 (center) |S32 dask.array<chunksize=(3,), meta=np.ndarray>
#     ...                     ...
#     mlc_natl_att           int16 ...
#     mlc_natl_lat           (time) float32 dask.array<chunksize=(50,), meta=np.ndarray>
#     mlc_natl_lon           (time) float32 dask.array<chunksize=(50,), meta=np.ndarray>
#     mlc_natl_wind          (time) int16 dask.array<chunksize=(50,), meta=np.ndarray>
# ...
