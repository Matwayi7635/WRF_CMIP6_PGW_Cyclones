# %%
import xarray as xr
ds = xr.open_dataset("/mnt/g/ERA_5_wspd_slp/wrf_schemes_d01/Era_wrf_data/Era_prior_events/msl_Ken.nc")
da = ds["var151"]*0.01  # Extract data array to hPa x1/100
da.isel(lat=20, lon=40).plot()
da
# Out:
# <xarray.DataArray 'var151' (time: 48, lat: 721, lon: 1440)>
# array([[[1014.8612 , 1014.8612 , 1014.8612 , ..., 1014.8612 ,
#          1014.8612 , 1014.8612 ],
#         [1015.0112 , 1015.0112 , 1015.0112 , ..., 1015.01373,
#          1015.01373, 1015.01373],
#         [1015.15875, 1015.15875, 1015.15625, ..., 1015.16125,
#          1015.16125, 1015.16125],
#         ...,
#         [1005.27625, 1005.27374, 1005.27124, ..., 1005.28625,
#          1005.28375, 1005.27875],
#         [1005.7962 , 1005.7937 , 1005.7937 , ..., 1005.8012 ,
#          1005.7987 , 1005.7987 ],
#         [1006.01874, 1006.01874, 1006.01874, ..., 1006.01874,
#          1006.01874, 1006.01874]],
#
#        [[1014.8562 , 1014.8562 , 1014.8562 , ..., 1014.8562 ,
#          1014.8562 , 1014.8562 ],
#         [1014.9887 , 1014.9887 , 1014.9887 , ..., 1014.9912 ,
#          1014.9912 , 1014.9912 ],
#         [1015.1137 , 1015.1137 , 1015.1112 , ..., 1015.1187 ,
#          1015.1162 , 1015.1162 ],
# ...
# ...

# %%
import xarray as xr
ds = xr.open_dataset("/mnt/g/ERA_5_wspd_slp/wrf_schemes_d01/Era_wrf_data/Era_prior_events/msl_gust_10uv_Idai.nc")
#da = ds["var151"]*0.01  # Extract data array to hPa x1/100
#da.isel(lat=20, lon=40).plot()
#da
u = ds.u10.isel(latitude=20, longitude=40)
v = ds.v10.isel(latitude=20, longitude=40)
ws = (u**2 + v**2)**0.5
ws.plot()
