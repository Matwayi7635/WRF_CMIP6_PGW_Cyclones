# %%
from scipy.io.netcdf import netcdf_file as Dataset
import numpy as np
from scipy.ndimage.filters import gaussian_filter

import matplotlib as mpl
mpl.use('agg')
from mpl_toolkits.basemap import Basemap
from scipy.io import netcdf_file as nc
from pylab import *

from datetime import datetime   ########
from datetime import timedelta  ########
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from mpl_toolkits.basemap import Basemap, addcyclic
from scipy.ndimage.filters import minimum_filter, maximum_filter

import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import datetime as dt
import array as arr
from matplotlib import pyplot as plt
from matplotlib import dates
from datetime import datetime
import sys
from matplotlib.ticker import FormatStrFormatter

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.cbook as cbook

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import matplotlib.pyplot as plt 
import matplotlib.pyplot as plt
#import seaborn as sns; sns.set()
import numpy as np

c1 = plt.imread("/mnt/g/ERA_5_wspd_slp/wrf_schemes_d01/Era_wrf_data/Plots/TT_dew.png")
#plt.imshow(c1)

# A png image
c2 = plt.imread("/mnt/g/ERA_5_wspd_slp/wrf_schemes_d01/Era_wrf_data/Plots/TT_INDEX.png")
#plt.axis('off')
#plt.imshow(c2)

c3 = plt.imread("/mnt/g/ERA_5_wspd_slp/wrf_schemes_d01/Era_wrf_data/Plots/wind.png")
#plt.axis('off')

c4 = plt.imread("/mnt/g/ERA_5_wspd_slp/wrf_schemes_d01/Era_wrf_data/Plots/cloud.png")
#plt.axis('off')

############################################33
fig = plt.figure(figsize=(5, 4))

#fig, (ax1, ax2, ax3) = plt.subplots(3,1)         for sama 



#im1 = ax1.imshow(c1)#,aspect="auto")#, norm=LogNorm(vmin=0.001, vmax=1), aspect='auto')
#ax1.axis('off')

#im2 = ax2.imshow(c2)#, norm=LogNorm(vmin=0.001, vmax=1), aspect='auto')
#ax2.axis('off')

#im3 = ax3.imshow(c3)#, norm=LogNorm(vmin=0.001, vmax=1), aspect='auto')
#ax3.axis('off')

fig, axs = plt.subplots(2, 2)


axs[0, 0].imshow(c1)
axs[0, 0].axis('off')
#axs[0, 0].set_title('geop500',fontsize=6)
axs[0, 1].imshow(c2)
axs[0, 1].axis('off')
#axs[0, 1].set_title('geop500',fontsize=6)
#axs[0, 1].set_title('Axis [0,1]')

axs[1, 0].imshow(c3)
axs[1, 0].axis('off')
#axs[1, 0].set_title('geop500',fontsize=6)
axs[1, 1].imshow(c4)
axs[1, 1].axis('off')
#axs[1, 1].set_title('geop500',fontsize=6)




#plt.axis('off')
plt.tight_layout()
# Make space for title
#pyplot.subplots_adjust(hspace=0, wspace=0)
plt.subplots_adjust(hspace=-0.01, wspace=-.2)
plt.show()


suptitle('Chouf District (Latitude 33.7 N, Longitude 35.6 E)',fontsize=8,weight='bold')

savefig("/mnt/g/ERA_5_wspd_slp/wrf_schemes_d01/Era_wrf_data/Plots/2d_panel.png", bbox_inches='tight', pad_inches=.3, dpi=300)
savefig("/mnt/g/ERA_5_wspd_slp/wrf_schemes_d01/Era_wrf_data/Plots/2d_panel.pdf", bbox_inches='tight', pad_inches=.3, dpi=300)
